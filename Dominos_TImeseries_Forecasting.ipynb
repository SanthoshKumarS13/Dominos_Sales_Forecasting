# %% [markdown]
# # Loading the Data

# %% [markdown]
# ***Importing the Required Modules***
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
pizza_sales_data=pd.read_excel('/content/Pizza_Sales_Cleaned.xlsx')
pizza_sales_data.drop(['pizza_ingredients','pizza_name','total_price','unit_price','order_time','order_id','pizza_id','order_date_date','order_date_month','order_date_week'],axis=1,inplace=True)
pizza_sales_data.head()
# Out:
#    pizza_name_id  quantity order_date pizza_size pizza_category
# 0     hawaiian_m         1 2015-01-01          M        Classic
# 1  classic_dlx_m         1 2015-01-01          M        Classic
# 2  five_cheese_l         1 2015-01-01          L         Veggie
# 3    ital_supr_l         1 2015-01-01          L        Supreme
# 4     mexicana_m         1 2015-01-01          M         Veggie

# %% [markdown]
# # Project Approch
#
# 1.   Try Four Different Time Series Forecasting Model:
#
# <div align="center">
#
# |   **Model**     |
# |-----------------|
# | 1. **ARIMA**    |
# | 2. **SARIMA**   |
# | 3. **Prophet**  |
# | 4. **XGBoost**  |
#
# </div>
#
# 2. Finding out Which model is performance is Good in ForeCasting.
#
# 3. If All the Model overrall Performance is not so good Means Combine all Four Models and Take a pizza_name_id forcasted Quantity based on the individual pizaa_name_id Mape Scores.

# %%
# !pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (7.8 kB)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (3.0.11)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.5.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (1.13.1)
# Requirement already satisfied: statsmodels>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (0.14.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (2.2.3)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (71.0.4)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pmdarima) (24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.19->pmdarima) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->pmdarima) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.13.2->pmdarima) (0.5.6)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Downloading pmdarima-2.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 28.3 MB/s eta 0:00:00
# Installing collected packages: pmdarima
# Successfully installed pmdarima-2.0.4

# %% [markdown]
# **Extracting the first Date of the every week and Making the Data ready for the Model**

# %%
# Step 1: Data Preparation
def prepare_data(df):
    df['order_date'] = pd.to_datetime(df['order_date'])
    df['week'] = df['order_date'].dt.to_period('W').apply(lambda r: r.start_time)
    weekly_sales_by_pizza = df.groupby(['week', 'pizza_name_id'])['quantity'].sum().reset_index()
    weekly_sales_by_pizza.set_index('week', inplace=True)
    return weekly_sales_by_pizza

# %% [markdown]
# **Splitting the Data for Testing and Training by 30:70 Ratio**

# %%
# Step 2: Split data into training and test sets
def split_data(pizza_type_data, train_size=0.7):
    train_size = int(train_size * len(pizza_type_data))
    train_data = pizza_type_data[:train_size]['quantity']
    test_data = pizza_type_data[train_size:]['quantity']
    return train_data, test_data

# %% [markdown]
# # ARIMA MODEL

# %% [markdown]
# **Importing the required Modules for the ARIMA MODEL**

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_percentage_error
from pmdarima import auto_arima

# %% [markdown]
# **Calculating and optimizing the Model for Better Mape scores**

# %%
# Step 3: Calculate MAPE
def calculate_mape(actual, predicted):
    return mean_absolute_percentage_error(actual, predicted)

# Step 4: Optimize ARIMA Model and Forecast
def auto_tune_arima(train_data, test_data):
    model = auto_arima(train_data, start_p=1, start_q=1, max_p=5, max_q=5,
                       seasonal=False, trace=False, error_action='ignore',
                       suppress_warnings=True, stepwise=True)
    predictions = model.predict(n_periods=len(test_data))
    mape = calculate_mape(test_data, predictions)
    return predictions, mape, model

# %% [markdown]
# **ForeCasting the Next Week sales**

# %%
# Step 5: Forecast the next week for each pizza_name_id
def forecast_next_week(pizza_sales_weekly_by_pizza, periods=1):
    forecasts = []
    overall_mape = []
    last_week = pizza_sales_weekly_by_pizza.index.max()
    next_week_start = last_week + pd.Timedelta(weeks=1)

    # List to store data for the DataFrame
    forecast_data = []

    # Forecast for each pizza type
    for pizza_id in pizza_sales_weekly_by_pizza['pizza_name_id'].unique():
        pizza_type_data = pizza_sales_weekly_by_pizza[pizza_sales_weekly_by_pizza['pizza_name_id'] == pizza_id]

        # Split data into train and test
        train_data, test_data = split_data(pizza_type_data)

        # Optimize ARIMA model and forecast
        if len(train_data) > 5:  # Ensure there is enough data
            predictions, mape, model = auto_tune_arima(train_data, test_data)
            overall_mape.append(mape)

            # Forecast the next period (next week)
            forecast = model.predict(n_periods=periods)
            forecast_value = forecast.iloc[0]  # Access the first element using iloc

            # Append data to the list for DataFrame
            forecast_data.append({
                'pizza_name_id': pizza_id,
                'predicted_quantity': int(forecast_value),
                'mape': mape
            })
        else:
            print(f"Not enough data to train ARIMA model for pizza_id {pizza_id}")

    # Convert the list of dictionaries into a DataFrame
    forecast_df = pd.DataFrame(forecast_data)

    # Calculate the overall MAPE score
    avg_mape = sum(overall_mape) / len(overall_mape) if overall_mape else 0  # Handle empty list
    return forecast_df, avg_mape, next_week_start

# %% [markdown]
# **Diplaying the Forcasted Quantity for Next Week**

# %%
# Step 6: Display Forecast Results
def display_forecasts(forecast_df, next_week_start):
    print(f"Forecasted sales for the week starting {next_week_start.date()}:")
    for index, row in forecast_df.iterrows():
        print(f"Pizza ID {row['pizza_name_id']}: {row['predicted_quantity']} pizzas, MAPE: {row['mape']:.2%}")

    print("\nOverall Forecast DataFrame:")
    print(forecast_df)

# %% [markdown]
# **Calling All the Function to Executing**

# %%
# Main Execution
if __name__ == "__main__":

    # Prepare the data
    pizza_sales_weekly_by_pizza = prepare_data(pizza_sales_data)

    # Forecast next week sales and store results in a DataFrame
    forecast_df, avg_mape, next_week_start = forecast_next_week(pizza_sales_weekly_by_pizza)

    # Display the forecasted results along with MAPE
    display_forecasts(forecast_df, next_week_start)

    forecast_df.to_csv('ARIMA_Forecasted_result.csv', index=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# Forecasted sales for the week starting 2016-01-04:
# Pizza ID bbq_ckn_l: 19 pizzas, MAPE: 32.81%
# Pizza ID bbq_ckn_m: 18 pizzas, MAPE: 42.20%
# Pizza ID bbq_ckn_s: 8 pizzas, MAPE: 28.50%
# Pizza ID big_meat_s: 37 pizzas, MAPE: 21.10%
# Pizza ID brie_carre_s: 9 pizzas, MAPE: 38.00%
# Pizza ID calabrese_l: 0 pizzas, MAPE: 57.39%
# Pizza ID calabrese_m: 10 pizzas, MAPE: 46.39%
# Pizza ID cali_ckn_l: 17 pizzas, MAPE: 36.30%
# Pizza ID cali_ckn_m: 18 pizzas, MAPE: 36.90%
# Pizza ID cali_ckn_s: 9 pizzas, MAPE: 46.21%
# Pizza ID ckn_alfredo_l: 3 pizzas, MAPE: 53.72%
# Pizza ID ckn_alfredo_m: 13 pizzas, MAPE: 26.11%
# Pizza ID ckn_alfredo_s: 2 pizzas, MAPE: 64.99%
# Pizza ID ckn_pesto_l: 8 pizzas, MAPE: 72.61%
# Pizza ID ckn_pesto_m: 5 pizzas, MAPE: 48.23%
# Pizza ID ckn_pesto_s: 5 pizzas, MAPE: 54.08%
# Pizza ID classic_dlx_l: 8 pizzas, MAPE: 18.75%
# Pizza ID classic_dlx_m: 23 pizzas, MAPE: 18.46%
# Pizza ID classic_dlx_s: 14 pizzas, MAPE: 23.61%
# Pizza ID five_cheese_l: 27 pizzas, MAPE: 37.26%
# Pizza ID four_cheese_l: 25 pizzas, MAPE: 29.45%
# Pizza ID four_cheese_m: 10 pizzas, MAPE: 41.75%
# Pizza ID green_garden_l: 1 pizzas, MAPE: 74.92%
# Pizza ID green_garden_m: 5 pizzas, MAPE: 51.13%
# Pizza ID green_garden_s: 10 pizzas, MAPE: 30.15%
# Pizza ID hawaiian_l: 16 pizzas, MAPE: 24.92%
# Pizza ID hawaiian_m: 8 pizzas, MAPE: 53.80%
# Pizza ID hawaiian_s: 18 pizzas, MAPE: 26.10%
# Pizza ID ital_cpcllo_l: 14 pizzas, MAPE: 53.18%
# Pizza ID ital_cpcllo_m: 8 pizzas, MAPE: 59.86%
# Pizza ID ital_cpcllo_s: 5 pizzas, MAPE: 50.43%
# Pizza ID ital_supr_l: 14 pizzas, MAPE: 34.58%
# Pizza ID ital_supr_m: 18 pizzas, MAPE: 43.32%
# Pizza ID ital_supr_s: 3 pizzas, MAPE: 75.26%
# Pizza ID ital_veggie_m: 8 pizzas, MAPE: 51.90%
# Pizza ID ital_veggie_s: 6 pizzas, MAPE: 52.10%
# Pizza ID mediterraneo_l: 7 pizzas, MAPE: 58.54%
# Pizza ID mediterraneo_m: 4 pizzas, MAPE: 34.34%
# Pizza ID mediterraneo_s: 5 pizzas, MAPE: 46.21%
# Pizza ID mexicana_l: 16 pizzas, MAPE: 31.03%
# Pizza ID mexicana_m: 9 pizzas, MAPE: 66.40%
# Pizza ID mexicana_s: 3 pizzas, MAPE: 41.34%
# Pizza ID napolitana_l: 11 pizzas, MAPE: 55.28%
# Pizza ID napolitana_m: 8 pizzas, MAPE: 48.47%
# Pizza ID napolitana_s: 9 pizzas, MAPE: 30.96%
# Pizza ID pep_msh_pep_l: 7 pizzas, MAPE: 44.34%
# Pizza ID pep_msh_pep_m: 7 pizzas, MAPE: 32.53%
# Pizza ID pep_msh_pep_s: 11 pizzas, MAPE: 72.97%
# Pizza ID pepperoni_l: 14 pizzas, MAPE: 32.90%
# Pizza ID pepperoni_m: 18 pizzas, MAPE: 34.36%
# Pizza ID pepperoni_s: 14 pizzas, MAPE: 36.40%
# Pizza ID peppr_salami_l: 14 pizzas, MAPE: 54.44%
# Pizza ID peppr_salami_m: 7 pizzas, MAPE: 36.13%
# Pizza ID peppr_salami_s: 5 pizzas, MAPE: 38.47%
# Pizza ID prsc_argla_l: 8 pizzas, MAPE: 35.40%
# Pizza ID prsc_argla_m: 11 pizzas, MAPE: 97.56%
# Pizza ID prsc_argla_s: 8 pizzas, MAPE: 65.85%
# Pizza ID sicilian_l: 11 pizzas, MAPE: 23.85%
# Pizza ID sicilian_m: 11 pizzas, MAPE: 106.33%
# Pizza ID sicilian_s: 14 pizzas, MAPE: 58.91%
# Pizza ID soppressata_l: 8 pizzas, MAPE: 62.66%
# Pizza ID soppressata_m: 5 pizzas, MAPE: 121.46%
# Pizza ID soppressata_s: 5 pizzas, MAPE: 39.31%
# Pizza ID southw_ckn_l: 18 pizzas, MAPE: 28.86%
# Pizza ID southw_ckn_m: 9 pizzas, MAPE: 30.77%
# Pizza ID southw_ckn_s: 7 pizzas, MAPE: 102.83%
# Pizza ID spicy_ital_l: 22 pizzas, MAPE: 48.93%
# Pizza ID spicy_ital_m: 7 pizzas, MAPE: 44.83%
# Pizza ID spicy_ital_s: 8 pizzas, MAPE: 51.72%
# Pizza ID spin_pesto_l: 5 pizzas, MAPE: 49.05%
# Pizza ID spin_pesto_m: 5 pizzas, MAPE: 34.11%
# Pizza ID spin_pesto_s: 7 pizzas, MAPE: 51.35%
# Pizza ID spinach_fet_l: 8 pizzas, MAPE: 71.50%
# Pizza ID spinach_fet_m: 11 pizzas, MAPE: 46.14%
# Pizza ID spinach_fet_s: 7 pizzas, MAPE: 57.15%
# Pizza ID spinach_supr_l: 5 pizzas, MAPE: 87.83%
# Pizza ID spinach_supr_m: 4 pizzas, MAPE: 56.25%
# Pizza ID spinach_supr_s: 7 pizzas, MAPE: 102.15%
# Pizza ID thai_ckn_l: 26 pizzas, MAPE: 28.38%
# Pizza ID thai_ckn_m: 10 pizzas, MAPE: 34.86%
# Pizza ID thai_ckn_s: 9 pizzas, MAPE: 44.23%
# Pizza ID the_greek_l: 4 pizzas, MAPE: 83.65%
# Pizza ID the_greek_m: 5 pizzas, MAPE: 46.50%
# Pizza ID the_greek_s: 5 pizzas, MAPE: 54.30%
# Pizza ID the_greek_xl: 10 pizzas, MAPE: 55.73%
# Pizza ID veggie_veg_l: 8 pizzas, MAPE: 48.64%
# Pizza ID veggie_veg_m: 12 pizzas, MAPE: 35.31%
# Pizza ID veggie_veg_s: 10 pizzas, MAPE: 76.81%
# Pizza ID calabrese_s: 2 pizzas, MAPE: 81.93%
# Pizza ID ital_veggie_l: 3 pizzas, MAPE: 46.57%
# Pizza ID the_greek_xxl: 1 pizzas, MAPE: 29.52%
#
# Overall Forecast DataFrame:
#     pizza_name_id  predicted_quantity      mape
# 0       bbq_ckn_l                  19  0.328097
# 1       bbq_ckn_m                  18  0.421951
# 2       bbq_ckn_s                   8  0.284963
# 3      big_meat_s                  37  0.211025
# 4    brie_carre_s                   9  0.380018
# ..            ...                 ...       ...
# 86   veggie_veg_m                  12  0.353143
# 87   veggie_veg_s                  10  0.768118
# 88    calabrese_s                   2  0.819313
# 89  ital_veggie_l                   3  0.465683
# 90  the_greek_xxl                   1  0.295238
#
# [91 rows x 3 columns]
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %% [markdown]
# # SARIMA MODEL

# %% [markdown]
# **Import Statements**

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_percentage_error
import warnings

# Import ConvergenceWarning from statsmodels.tools.sm_exceptions
from statsmodels.tools.sm_exceptions import ConvergenceWarning

# Instead of importing ValueWarning directly, catch it using its parent class
warnings.filterwarnings("ignore", category=UserWarning) # Changed this line
warnings.filterwarnings("ignore", category=ConvergenceWarning)

# %% [markdown]
# **Traing and Forecasting the Quantity sold for each Pizza Types**

# %%
def forecast_sales_per_pizza_type(pizza_type, train, test, periods=1):
    # Train the SARIMA model
    model = SARIMAX(train, order=(1, 0, 1), seasonal_order=(1, 0, 1, 7))
    model_fit = model.fit(disp=False)

    # Forecast for the next week
    forecast = model_fit.forecast(steps=periods)

    # Calculate MAPE on test data (actual vs forecasted)
    if len(test) > 0:
        predictions = model_fit.forecast(steps=len(test))
        mape = calculate_mape(test, predictions)
    else:
        mape = np.nan  # Not enough data to calculate MAPE

    # Return the pizza type, forecasted quantity, and MAPE
    return pizza_type, forecast.tolist(), mape

# %% [markdown]
# **Forcasting the Quantity for Next Week**

# %%
def forecast_next_week_sales_by_pizza_type(pizza_sales_weekly_by_pizza, periods=1):
    pizza_type_forecasts = {}
    mape_scores = {}

    # Get the last week's date range (for prediction display purposes)
    last_week = pizza_sales_weekly_by_pizza.index.max()
    next_week_start = last_week + pd.Timedelta(weeks=1)
    next_week_end = next_week_start + pd.Timedelta(days=6)

    # Loop through each pizza type
    for pizza_type in pizza_sales_weekly_by_pizza['pizza_name_id'].unique():
        # Filter the data for this pizza type
        pizza_type_data = pizza_sales_weekly_by_pizza[pizza_sales_weekly_by_pizza['pizza_name_id'] == pizza_type]

        # Split into training and testing data (80% training, 20% testing)
        train_size = int(0.7 * len(pizza_type_data))
        train = pizza_type_data[:train_size]['quantity']
        test = pizza_type_data[train_size:]['quantity']

        # Forecast sales for the next week for this pizza type
        pizza_type, forecast, mape = forecast_sales_per_pizza_type(pizza_type, train, test, periods)

        # Store the forecast and MAPE in dictionaries
        if forecast:
            pizza_type_forecasts[pizza_type] = forecast[0]  # Access the first value of the forecast list
            mape_scores[pizza_type] = mape

    return pizza_type_forecasts, mape_scores, next_week_start, next_week_end

# %% [markdown]
# **Final Calling and creating the Dataframe**

# %%
# Step 4: Forecast pizza sales for the next week and calculate MAPE
next_week_pizza_sales_forecasts, mape_scores, next_week_start, next_week_end = forecast_next_week_sales_by_pizza_type(pizza_sales_weekly_by_pizza, periods=1)

# Step 5: Display the forecasted sales and MAPE for each pizza type
print(f"Forecasted sales for the week starting {next_week_start.date()}")

total_forecasted_quantity = 0  # To accumulate the forecasted quantities

for pizza_type, forecast in next_week_pizza_sales_forecasts.items():
    forecast = int(forecast)
    print(f'{pizza_type}: {forecast} pizzas')
    total_forecasted_quantity += forecast

# Display total quantity of pizzas forecasted
print(f"Total quantity of units forecasted to be sold in the next week: {total_forecasted_quantity} pizzas")

# Display MAPE for each pizza type
print("\nMAPE scores:")
for pizza_type, mape in mape_scores.items():
    print(f"{pizza_type}: {mape:.2f}%")

# Step 6: Create a DataFrame with pizza_name_id, next week quantity, and MAPE
forecast_df = pd.DataFrame({
    'pizza_name_id': list(next_week_pizza_sales_forecasts.keys()),
    'next_week_quantity': list(next_week_pizza_sales_forecasts.values()),
    'MAPE': list(mape_scores.values())
})

# Step 7: Export the DataFrame to a CSV file
forecast_df.to_csv("SARIMA_Forecasted_Result.csv", index=False)
# Out:
# Forecasted sales for the week starting 2016-01-04
# bbq_ckn_l: 17 pizzas
# bbq_ckn_m: 18 pizzas
# bbq_ckn_s: 9 pizzas
# big_meat_s: 39 pizzas
# brie_carre_s: 8 pizzas
# calabrese_l: 2 pizzas
# calabrese_m: 9 pizzas
# cali_ckn_l: 18 pizzas
# cali_ckn_m: 18 pizzas
# cali_ckn_s: 8 pizzas
# ckn_alfredo_l: 4 pizzas
# ckn_alfredo_m: 13 pizzas
# ckn_alfredo_s: 2 pizzas
# ckn_pesto_l: 8 pizzas
# ckn_pesto_m: 4 pizzas
# ckn_pesto_s: 5 pizzas
# classic_dlx_l: 7 pizzas
# classic_dlx_m: 22 pizzas
# classic_dlx_s: 14 pizzas
# five_cheese_l: 27 pizzas
# four_cheese_l: 25 pizzas
# four_cheese_m: 10 pizzas
# green_garden_l: 1 pizzas
# green_garden_m: 6 pizzas
# green_garden_s: 11 pizzas
# hawaiian_l: 14 pizzas
# hawaiian_m: 9 pizzas
# hawaiian_s: 19 pizzas
# ital_cpcllo_l: 14 pizzas
# ital_cpcllo_m: 8 pizzas
# ital_cpcllo_s: 7 pizzas
# ital_supr_l: 14 pizzas
# ital_supr_m: 19 pizzas
# ital_supr_s: 3 pizzas
# ital_veggie_m: 9 pizzas
# ital_veggie_s: 5 pizzas
# mediterraneo_l: 6 pizzas
# mediterraneo_m: 3 pizzas
# mediterraneo_s: 4 pizzas
# mexicana_l: 16 pizzas
# mexicana_m: 9 pizzas
# mexicana_s: 3 pizzas
# napolitana_l: 11 pizzas
# napolitana_m: 8 pizzas
# napolitana_s: 9 pizzas
# pep_msh_pep_l: 5 pizzas
# pep_msh_pep_m: 7 pizzas
# pep_msh_pep_s: 11 pizzas
# pepperoni_l: 14 pizzas
# pepperoni_m: 19 pizzas
# pepperoni_s: 14 pizzas
# peppr_salami_l: 12 pizzas
# peppr_salami_m: 8 pizzas
# peppr_salami_s: 5 pizzas
# prsc_argla_l: 8 pizzas
# prsc_argla_m: 11 pizzas
# prsc_argla_s: 8 pizzas
# sicilian_l: 11 pizzas
# sicilian_m: 11 pizzas
# sicilian_s: 14 pizzas
# soppressata_l: 7 pizzas
# soppressata_m: 5 pizzas
# soppressata_s: 5 pizzas
# southw_ckn_l: 17 pizzas
# southw_ckn_m: 10 pizzas
# southw_ckn_s: 7 pizzas
# spicy_ital_l: 21 pizzas
# spicy_ital_m: 7 pizzas
# spicy_ital_s: 7 pizzas
# spin_pesto_l: 5 pizzas
# spin_pesto_m: 5 pizzas
# spin_pesto_s: 7 pizzas
# spinach_fet_l: 8 pizzas
# spinach_fet_m: 11 pizzas
# spinach_fet_s: 6 pizzas
# spinach_supr_l: 9 pizzas
# spinach_supr_m: 4 pizzas
# spinach_supr_s: 8 pizzas
# thai_ckn_l: 27 pizzas
# thai_ckn_m: 9 pizzas
# thai_ckn_s: 8 pizzas
# the_greek_l: 5 pizzas
# the_greek_m: 5 pizzas
# the_greek_s: 5 pizzas
# the_greek_xl: 10 pizzas
# veggie_veg_l: 7 pizzas
# veggie_veg_m: 13 pizzas
# veggie_veg_s: 8 pizzas
# calabrese_s: 2 pizzas
# ital_veggie_l: 3 pizzas
# the_greek_xxl: 1 pizzas
# Total quantity of units forecasted to be sold in the next week: 905 pizzas
#
# MAPE scores:
# bbq_ckn_l: 0.33%
# bbq_ckn_m: 0.43%
# bbq_ckn_s: 0.37%
# big_meat_s: 0.24%
# brie_carre_s: 0.39%
# calabrese_l: 0.64%
# calabrese_m: 0.48%
# cali_ckn_l: 0.38%
# cali_ckn_m: 0.37%
# cali_ckn_s: 0.47%
# ckn_alfredo_l: 0.64%
# ckn_alfredo_m: 0.26%
# ckn_alfredo_s: 0.64%
# ckn_pesto_l: 0.75%
# ckn_pesto_m: 0.44%
# ckn_pesto_s: 0.52%
# classic_dlx_l: 0.27%
# classic_dlx_m: 0.18%
# classic_dlx_s: 0.25%
# five_cheese_l: 0.39%
# four_cheese_l: 0.29%
# four_cheese_m: 0.42%
# green_garden_l: 0.78%
# green_garden_m: 0.66%
# green_garden_s: 0.33%
# hawaiian_l: 0.27%
# hawaiian_m: 0.62%
# hawaiian_s: 0.26%
# ital_cpcllo_l: 0.54%
# ital_cpcllo_m: 0.62%
# ital_cpcllo_s: 0.52%
# ital_supr_l: 0.36%
# ital_supr_m: 0.44%
# ital_supr_s: 0.77%
# ital_veggie_m: 0.51%
# ital_veggie_s: 0.48%
# mediterraneo_l: 0.56%
# mediterraneo_m: 0.40%
# mediterraneo_s: 0.45%
# mexicana_l: 0.31%
# mexicana_m: 0.74%
# mexicana_s: 0.45%
# napolitana_l: 0.59%
# napolitana_m: 0.49%
# napolitana_s: 0.33%
# pep_msh_pep_l: 0.55%
# pep_msh_pep_m: 0.32%
# pep_msh_pep_s: 0.71%
# pepperoni_l: 0.33%
# pepperoni_m: 0.32%
# pepperoni_s: 0.36%
# peppr_salami_l: 0.52%
# peppr_salami_m: 0.36%
# peppr_salami_s: 0.38%
# prsc_argla_l: 0.35%
# prsc_argla_m: 1.01%
# prsc_argla_s: 0.66%
# sicilian_l: 0.24%
# sicilian_m: 1.04%
# sicilian_s: 0.58%
# soppressata_l: 0.62%
# soppressata_m: 1.27%
# soppressata_s: 0.39%
# southw_ckn_l: 0.29%
# southw_ckn_m: 0.31%
# southw_ckn_s: 1.09%
# spicy_ital_l: 0.44%
# spicy_ital_m: 0.45%
# spicy_ital_s: 0.52%
# spin_pesto_l: 0.47%
# spin_pesto_m: 0.32%
# spin_pesto_s: 0.50%
# spinach_fet_l: 0.67%
# spinach_fet_m: 0.46%
# spinach_fet_s: 0.35%
# spinach_supr_l: 0.95%
# spinach_supr_m: 0.52%
# spinach_supr_s: 1.02%
# thai_ckn_l: 0.29%
# thai_ckn_m: 0.37%
# thai_ckn_s: 0.43%
# the_greek_l: 0.90%
# the_greek_m: 0.46%
# the_greek_s: 0.52%
# the_greek_xl: 0.56%
# veggie_veg_l: 0.45%
# veggie_veg_m: 0.37%
# veggie_veg_s: 0.78%
# calabrese_s: 0.79%
# ital_veggie_l: 0.44%
# the_greek_xxl: 0.29%

# %% [markdown]
# **PROPHET MODEL**

# %% [markdown]
# **Import Statements**

# %%
import pandas as pd
import numpy as np
from prophet import Prophet
import warnings

# %% [markdown]
# **Training the Prophet model and Forcasting the Sales**

# %%
def train_and_forecast_sales_prophet(pizza_type, train_data, periods=1):
    """Train Prophet model and forecast sales for the next period."""
    # Prepare the data for Prophet
    train_data = train_data.reset_index()
    train_data.columns = ['ds', 'y']  # Rename columns for Prophet

    # Train the Prophet model
    model = Prophet()
    model.fit(train_data)

    # Create future dataframe for the next week
    future = model.make_future_dataframe(periods=periods, freq='W-SUN')  # Forecast weekly

    # Forecast the sales
    forecast = model.predict(future)

    # Get the forecasted sales for the next week
    next_week_forecast = forecast[['ds', 'yhat']].tail(periods)['yhat'].tolist()

    # Calculate MAPE on training data (excluding future predictions)
    train_forecast = forecast[['ds', 'yhat']].head(len(train_data))
    mape = calculate_mape(train_data['y'], train_forecast['yhat'])

    return pizza_type, next_week_forecast, mape

# %% [markdown]
# **Forecasting for the Next Week**

# %%
def forecast_next_week(pizza_sales_weekly_by_pizza, periods=1):
    """Forecast sales for the next week for all pizza types using Prophet."""
    pizza_type_forecasts = {}
    mape_scores = {}

    # Calculate total sales per pizza type
    total_units_sold = pizza_sales_weekly_by_pizza.groupby('pizza_name_id')['quantity'].sum()

    # Get the last week's date range
    last_week = pizza_sales_weekly_by_pizza.index.max()
    next_week_start = last_week + pd.Timedelta(weeks=1)
    next_week_end = next_week_start + pd.Timedelta(days=6)

    # Loop through each pizza type
    for pizza_type in pizza_sales_weekly_by_pizza['pizza_name_id'].unique():
        # Filter the data for this pizza type
        pizza_type_data = pizza_sales_weekly_by_pizza[pizza_sales_weekly_by_pizza['pizza_name_id'] == pizza_type]

        # Split into training data
        train_data = split_data(pizza_type_data)

        # Forecast sales for the next week for this pizza type
        pizza_type, forecast, mape = train_and_forecast_sales_prophet(pizza_type, train_data, periods)

        # Store the forecast in the dictionary
        if forecast:
            pizza_type_forecasts[pizza_type] = forecast[0]  # Access the first value of the forecast list
            mape_scores[pizza_type] = mape  # Store MAPE score

    return pizza_type_forecasts, mape_scores, total_units_sold, next_week_start, next_week_end

# %% [markdown]
# **Displaying the Results**

# %%
def display_forecasts(forecasts, mape_scores, next_week_start, next_week_end):
    """Display forecasted sales results and MAPE scores."""
    print(f"Forecasted sales for the week starting {next_week_start.date()}")
    total_forecasted_quantity = 0  # To accumulate the forecasted quantities

    # Loop through each forecast and display
    for pizza_type, forecast in forecasts.items():
        forecast = int(forecast)
        forecasts[pizza_type] = forecast
        print(f'{pizza_type}: {forecast} pizzas')
        total_forecasted_quantity += forecast

    # Display total quantity of pizzas forecasted
    print(f"Total quantity of units forecasted to be sold in the next week: {total_forecasted_quantity} pizzas")

    # Display MAPE for each pizza type
    print("\nMAPE scores:")
    for pizza_type, mape in mape_scores.items():
        print(f"{pizza_type}: {mape:.2f}%")

# %% [markdown]
# **Finally Calling all the Functions to Executing the code**

# %%
if __name__ == "__main__":
    # Prepare the data
    pizza_sales_weekly_by_pizza = prepare_data(pizza_sales_data)

    # Forecast pizza sales for the next week using Prophet
    forecasts, mape_scores, total_units_sold, next_week_start, next_week_end = forecast_next_week(pizza_sales_weekly_by_pizza, periods=1)

    # Create a DataFrame with pizza_name_id, next week quantity, and MAPE
    forecast_df = pd.DataFrame({
        'pizza_name_id': list(forecasts.keys()),
        'next_week_quantity': list(forecasts.values()),
        'MAPE': list(mape_scores.values())
    })

    # Display the forecasted results
    display_forecasts(forecasts, mape_scores, next_week_start, next_week_end)

    # Export the DataFrame to a CSV file
    forecast_df.to_csv("Prophet_Forecasted_Result.csv", index=False)
# Out:
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/a3k_z9mh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/d7cq31nr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29745', 'data', 'file=/tmp/tmpx6qsk0bj/a3k_z9mh.json', 'init=/tmp/tmpx6qsk0bj/d7cq31nr.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelbe18j1lg/prophet_model-20241004051838.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/nlcr3opc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/thsppm45.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77245', 'data', 'file=/tmp/tmpx6qsk0bj/nlcr3opc.json', 'init=/tmp/tmpx6qsk0bj/thsppm45.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_model1ul0vzlx/prophet_model-20241004051838.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/9x68fuxi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/cvzjrt2f.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74990', 'data', 'file=/tmp/tmpx6qsk0bj/9x68fuxi.json', 'init=/tmp/tmpx6qsk0bj/cvzjrt2f.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modeluip2y_wi/prophet_model-20241004051838.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/gc59qmnp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/6eowzmz_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32474', 'data', 'file=/tmp/tmpx6qsk0bj/gc59qmnp.json', 'init=/tmp/tmpx6qsk0bj/6eowzmz_.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modellk5qmmkd/prophet_model-20241004051839.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/_tx75ano.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/9fkixh6x.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98415', 'data', 'file=/tmp/tmpx6qsk0bj/_tx75ano.json', 'init=/tmp/tmpx6qsk0bj/9fkixh6x.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modell8c2xb6p/prophet_model-20241004051839.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/j70jvmu7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/yx5kbme6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88725', 'data', 'file=/tmp/tmpx6qsk0bj/j70jvmu7.json', 'init=/tmp/tmpx6qsk0bj/yx5kbme6.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_model58i_89ch/prophet_model-20241004051840.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/vmbay5ks.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/sq12slj3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61757', 'data', 'file=/tmp/tmpx6qsk0bj/vmbay5ks.json', 'init=/tmp/tmpx6qsk0bj/sq12slj3.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelh1niam_f/prophet_model-20241004051840.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/zo8ama36.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/qovnctc5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81044', 'data', 'file=/tmp/tmpx6qsk0bj/zo8ama36.json', 'init=/tmp/tmpx6qsk0bj/qovnctc5.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelxkm3_6_o/prophet_model-20241004051840.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/1w9s4x9w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/71yc54y8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=22438', 'data', 'file=/tmp/tmpx6qsk0bj/1w9s4x9w.json', 'init=/tmp/tmpx6qsk0bj/71yc54y8.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modeldnovhe_8/prophet_model-20241004051841.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/7a_0jsrw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/wotseik1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74932', 'data', 'file=/tmp/tmpx6qsk0bj/7a_0jsrw.json', 'init=/tmp/tmpx6qsk0bj/wotseik1.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelu9cjzfq1/prophet_model-20241004051841.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/sbgtao1k.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/96lt3sv6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58462', 'data', 'file=/tmp/tmpx6qsk0bj/sbgtao1k.json', 'init=/tmp/tmpx6qsk0bj/96lt3sv6.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelbbpwlkjq/prophet_model-20241004051841.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/dkc2r1y0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/s4xctzjf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52437', 'data', 'file=/tmp/tmpx6qsk0bj/dkc2r1y0.json', 'init=/tmp/tmpx6qsk0bj/s4xctzjf.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modellbihc7di/prophet_model-20241004051842.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 23.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/i8431arq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/pqzcipf7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71917', 'data', 'file=/tmp/tmpx6qsk0bj/i8431arq.json', 'init=/tmp/tmpx6qsk0bj/pqzcipf7.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modeljomgraba/prophet_model-20241004051842.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/lipto5za.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/hffoh4z7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99903', 'data', 'file=/tmp/tmpx6qsk0bj/lipto5za.json', 'init=/tmp/tmpx6qsk0bj/hffoh4z7.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_model31ndwqyj/prophet_model-20241004051842.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:42 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/m81t9u1f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/3x40uya7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39930', 'data', 'file=/tmp/tmpx6qsk0bj/m81t9u1f.json', 'init=/tmp/tmpx6qsk0bj/3x40uya7.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_model0nvharux/prophet_model-20241004051843.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/gfcovg9b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/7rcwxyi9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92730', 'data', 'file=/tmp/tmpx6qsk0bj/gfcovg9b.json', 'init=/tmp/tmpx6qsk0bj/7rcwxyi9.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelmzt49j_m/prophet_model-20241004051843.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/n0u1aspg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/h6p75e2l.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95166', 'data', 'file=/tmp/tmpx6qsk0bj/n0u1aspg.json', 'init=/tmp/tmpx6qsk0bj/h6p75e2l.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelk26ceprm/prophet_model-20241004051843.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:43 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/8adp4urm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/azhw9nud.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33366', 'data', 'file=/tmp/tmpx6qsk0bj/8adp4urm.json', 'init=/tmp/tmpx6qsk0bj/azhw9nud.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelmxprachj/prophet_model-20241004051843.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:43 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/cg06a6db.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/3z4x0v82.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28645', 'data', 'file=/tmp/tmpx6qsk0bj/cg06a6db.json', 'init=/tmp/tmpx6qsk0bj/3z4x0v82.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelujpt1je7/prophet_model-20241004051844.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/a8_hvwsk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/jbuih2f9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4128', 'data', 'file=/tmp/tmpx6qsk0bj/a8_hvwsk.json', 'init=/tmp/tmpx6qsk0bj/jbuih2f9.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelyvgwk6s9/prophet_model-20241004051844.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/fle7xyqk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/lrle5hu1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72446', 'data', 'file=/tmp/tmpx6qsk0bj/fle7xyqk.json', 'init=/tmp/tmpx6qsk0bj/lrle5hu1.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modeld8_uywwn/prophet_model-20241004051844.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:44 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/et4xgyxw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/34tsndap.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13058', 'data', 'file=/tmp/tmpx6qsk0bj/et4xgyxw.json', 'init=/tmp/tmpx6qsk0bj/34tsndap.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_model3l7g_fc9/prophet_model-20241004051844.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:44 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 24.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/42ksh2by.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/yb21y3rp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62783', 'data', 'file=/tmp/tmpx6qsk0bj/42ksh2by.json', 'init=/tmp/tmpx6qsk0bj/yb21y3rp.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modely6xxnr8a/prophet_model-20241004051845.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/1mbmwbw0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/f8gtpqws.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96015', 'data', 'file=/tmp/tmpx6qsk0bj/1mbmwbw0.json', 'init=/tmp/tmpx6qsk0bj/f8gtpqws.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelenhw2qa3/prophet_model-20241004051845.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/m2tsxu58.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/q58rdmqf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14020', 'data', 'file=/tmp/tmpx6qsk0bj/m2tsxu58.json', 'init=/tmp/tmpx6qsk0bj/q58rdmqf.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelp4phpilt/prophet_model-20241004051845.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:45 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/xtg2hshn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/m02qz8d4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91977', 'data', 'file=/tmp/tmpx6qsk0bj/xtg2hshn.json', 'init=/tmp/tmpx6qsk0bj/m02qz8d4.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_model614sjcxe/prophet_model-20241004051846.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/t5bof5fc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/bc_p03sm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23445', 'data', 'file=/tmp/tmpx6qsk0bj/t5bof5fc.json', 'init=/tmp/tmpx6qsk0bj/bc_p03sm.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelkuca9fju/prophet_model-20241004051846.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/uovol104.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/0bcjtped.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30470', 'data', 'file=/tmp/tmpx6qsk0bj/uovol104.json', 'init=/tmp/tmpx6qsk0bj/0bcjtped.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modela5_wjels/prophet_model-20241004051846.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:46 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/_4motdy3.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/d9z27878.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=94841', 'data', 'file=/tmp/tmpx6qsk0bj/_4motdy3.json', 'init=/tmp/tmpx6qsk0bj/d9z27878.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_model62wv913w/prophet_model-20241004051847.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/2_a56t3d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/yd7kc0_h.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80673', 'data', 'file=/tmp/tmpx6qsk0bj/2_a56t3d.json', 'init=/tmp/tmpx6qsk0bj/yd7kc0_h.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_model_2di8jfd/prophet_model-20241004051847.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:47 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/lp5cqsqq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/2zcctedp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4819', 'data', 'file=/tmp/tmpx6qsk0bj/lp5cqsqq.json', 'init=/tmp/tmpx6qsk0bj/2zcctedp.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modely_vpo8wr/prophet_model-20241004051847.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/5ipn479q.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/h343ctyq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83592', 'data', 'file=/tmp/tmpx6qsk0bj/5ipn479q.json', 'init=/tmp/tmpx6qsk0bj/h343ctyq.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelz6by2jy9/prophet_model-20241004051848.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:48 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:48 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/9pu5n3kp.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/l6vr60tz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56602', 'data', 'file=/tmp/tmpx6qsk0bj/9pu5n3kp.json', 'init=/tmp/tmpx6qsk0bj/l6vr60tz.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelfs8ua7tl/prophet_model-20241004051849.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/zkiunnbz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/gjv52afr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31684', 'data', 'file=/tmp/tmpx6qsk0bj/zkiunnbz.json', 'init=/tmp/tmpx6qsk0bj/gjv52afr.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelo1gx5_4j/prophet_model-20241004051849.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/ztkk7fx5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/c53rwbee.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4497', 'data', 'file=/tmp/tmpx6qsk0bj/ztkk7fx5.json', 'init=/tmp/tmpx6qsk0bj/c53rwbee.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelolx77cg2/prophet_model-20241004051849.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/s_k1mcxy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/epfbew8a.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58590', 'data', 'file=/tmp/tmpx6qsk0bj/s_k1mcxy.json', 'init=/tmp/tmpx6qsk0bj/epfbew8a.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_model805o1bzq/prophet_model-20241004051850.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/_9v3izzy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/b_zrdd61.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39363', 'data', 'file=/tmp/tmpx6qsk0bj/_9v3izzy.json', 'init=/tmp/tmpx6qsk0bj/b_zrdd61.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modeldti17223/prophet_model-20241004051851.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/dmlnuuo8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/8o9xl3l7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30071', 'data', 'file=/tmp/tmpx6qsk0bj/dmlnuuo8.json', 'init=/tmp/tmpx6qsk0bj/8o9xl3l7.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelhvij8_cp/prophet_model-20241004051851.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/rpkyv_2r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/6d46pqo3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7267', 'data', 'file=/tmp/tmpx6qsk0bj/rpkyv_2r.json', 'init=/tmp/tmpx6qsk0bj/6d46pqo3.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modeldfi2ccct/prophet_model-20241004051851.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/hykofav1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/fykxig1k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56695', 'data', 'file=/tmp/tmpx6qsk0bj/hykofav1.json', 'init=/tmp/tmpx6qsk0bj/fykxig1k.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelq0vdwt21/prophet_model-20241004051852.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/gqn7ganl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/wjjwzgga.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=76661', 'data', 'file=/tmp/tmpx6qsk0bj/gqn7ganl.json', 'init=/tmp/tmpx6qsk0bj/wjjwzgga.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_model0nfm1exo/prophet_model-20241004051852.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/4btbk8au.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/lou4znvx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96184', 'data', 'file=/tmp/tmpx6qsk0bj/4btbk8au.json', 'init=/tmp/tmpx6qsk0bj/lou4znvx.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelsyoxtybv/prophet_model-20241004051852.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/8oycp2l5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/25g1ju64.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46811', 'data', 'file=/tmp/tmpx6qsk0bj/8oycp2l5.json', 'init=/tmp/tmpx6qsk0bj/25g1ju64.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelr0xt0wcw/prophet_model-20241004051853.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/dsh9o77y.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/xwh129ef.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67157', 'data', 'file=/tmp/tmpx6qsk0bj/dsh9o77y.json', 'init=/tmp/tmpx6qsk0bj/xwh129ef.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelbchgyg7o/prophet_model-20241004051853.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/kl7rmq4l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/pmzvk1am.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58673', 'data', 'file=/tmp/tmpx6qsk0bj/kl7rmq4l.json', 'init=/tmp/tmpx6qsk0bj/pmzvk1am.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelfyg7a4pf/prophet_model-20241004051853.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:18:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:18:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# ...
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/i0dqb8ol.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/sr268b2e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8403', 'data', 'file=/tmp/tmpx6qsk0bj/i0dqb8ol.json', 'init=/tmp/tmpx6qsk0bj/sr268b2e.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_model_qsdhsis/prophet_model-20241004051902.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:19:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/h_1t6nhr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/ht4_pfmz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35020', 'data', 'file=/tmp/tmpx6qsk0bj/h_1t6nhr.json', 'init=/tmp/tmpx6qsk0bj/ht4_pfmz.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelyjzjld4t/prophet_model-20241004051902.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:19:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/r09o6fng.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/cw26zbgr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3933', 'data', 'file=/tmp/tmpx6qsk0bj/r09o6fng.json', 'init=/tmp/tmpx6qsk0bj/cw26zbgr.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelv1wyje6q/prophet_model-20241004051903.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:19:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/_iu_xj79.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/lae3nbkz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28177', 'data', 'file=/tmp/tmpx6qsk0bj/_iu_xj79.json', 'init=/tmp/tmpx6qsk0bj/lae3nbkz.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelx0jp_k3e/prophet_model-20241004051903.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:19:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/n1vq5vl9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/4wroejk_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47612', 'data', 'file=/tmp/tmpx6qsk0bj/n1vq5vl9.json', 'init=/tmp/tmpx6qsk0bj/4wroejk_.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modeld84qd792/prophet_model-20241004051903.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:19:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/hwg0vihh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/uet5z1bf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=41100', 'data', 'file=/tmp/tmpx6qsk0bj/hwg0vihh.json', 'init=/tmp/tmpx6qsk0bj/uet5z1bf.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_model5yxm526p/prophet_model-20241004051904.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:19:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/kb11an4c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/pk0uqi47.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=63501', 'data', 'file=/tmp/tmpx6qsk0bj/kb11an4c.json', 'init=/tmp/tmpx6qsk0bj/pk0uqi47.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_model24p0tj0i/prophet_model-20241004051904.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:19:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/v5e_dr58.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/z1jragnx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57728', 'data', 'file=/tmp/tmpx6qsk0bj/v5e_dr58.json', 'init=/tmp/tmpx6qsk0bj/z1jragnx.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelmazh_ptl/prophet_model-20241004051905.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:19:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 23.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/dsi_bbvw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/uxhuot61.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=34464', 'data', 'file=/tmp/tmpx6qsk0bj/dsi_bbvw.json', 'init=/tmp/tmpx6qsk0bj/uxhuot61.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelws_ug6fx/prophet_model-20241004051905.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:19:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/gznwidch.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/bi7t1r3p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98760', 'data', 'file=/tmp/tmpx6qsk0bj/gznwidch.json', 'init=/tmp/tmpx6qsk0bj/bi7t1r3p.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_model_v_s6un5/prophet_model-20241004051905.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:19:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:n_changepoints greater than number of observations. Using 11.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/jdiz0myf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx6qsk0bj/frhyt63m.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36842', 'data', 'file=/tmp/tmpx6qsk0bj/jdiz0myf.json', 'init=/tmp/tmpx6qsk0bj/frhyt63m.json', 'output', 'file=/tmp/tmpx6qsk0bj/prophet_modelmgne1o0k/prophet_model-20241004051906.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 05:19:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# Forecasted sales for the week 2016-01-04 to 2016-01-10:
# bbq_ckn_l: 16 pizzas
# bbq_ckn_m: 18 pizzas
# bbq_ckn_s: 9 pizzas
# big_meat_s: 40 pizzas
# brie_carre_s: 9 pizzas
# calabrese_l: 5 pizzas
# calabrese_m: 8 pizzas
# cali_ckn_l: 18 pizzas
# cali_ckn_m: 18 pizzas
# cali_ckn_s: 9 pizzas
# ckn_alfredo_l: 3 pizzas
# ckn_alfredo_m: 14 pizzas
# ckn_alfredo_s: 2 pizzas
# ckn_pesto_l: 6 pizzas
# ckn_pesto_m: 4 pizzas
# ckn_pesto_s: 6 pizzas
# classic_dlx_l: 8 pizzas
# classic_dlx_m: 23 pizzas
# classic_dlx_s: 15 pizzas
# five_cheese_l: 27 pizzas
# four_cheese_l: 24 pizzas
# four_cheese_m: 10 pizzas
# green_garden_l: 2 pizzas
# green_garden_m: 6 pizzas
# green_garden_s: 11 pizzas
# hawaiian_l: 17 pizzas
# hawaiian_m: 10 pizzas
# hawaiian_s: 17 pizzas
# ital_cpcllo_l: 15 pizzas
# ital_cpcllo_m: 7 pizzas
# ital_cpcllo_s: 4 pizzas
# ital_supr_l: 14 pizzas
# ital_supr_m: 19 pizzas
# ital_supr_s: 3 pizzas
# ital_veggie_m: 8 pizzas
# ital_veggie_s: 5 pizzas
# mediterraneo_l: 6 pizzas
# mediterraneo_m: 5 pizzas
# mediterraneo_s: 5 pizzas
# mexicana_l: 17 pizzas
# mexicana_m: 9 pizzas
# mexicana_s: 3 pizzas
# napolitana_l: 10 pizzas
# napolitana_m: 9 pizzas
# napolitana_s: 10 pizzas
# pep_msh_pep_l: 7 pizzas
# pep_msh_pep_m: 7 pizzas
# pep_msh_pep_s: 11 pizzas
# pepperoni_l: 14 pizzas
# pepperoni_m: 20 pizzas
# pepperoni_s: 13 pizzas
# peppr_salami_l: 12 pizzas
# peppr_salami_m: 8 pizzas
# peppr_salami_s: 4 pizzas
# prsc_argla_l: 7 pizzas
# prsc_argla_m: 12 pizzas
# prsc_argla_s: 8 pizzas
# sicilian_l: 11 pizzas
# sicilian_m: 11 pizzas
# sicilian_s: 13 pizzas
# soppressata_l: 8 pizzas
# soppressata_m: 6 pizzas
# soppressata_s: 5 pizzas
# southw_ckn_l: 21 pizzas
# southw_ckn_m: 10 pizzas
# southw_ckn_s: 8 pizzas
# spicy_ital_l: 24 pizzas
# spicy_ital_m: 8 pizzas
# spicy_ital_s: 7 pizzas
# spin_pesto_l: 6 pizzas
# spin_pesto_m: 5 pizzas
# spin_pesto_s: 6 pizzas
# spinach_fet_l: 9 pizzas
# spinach_fet_m: 12 pizzas
# spinach_fet_s: 7 pizzas
# spinach_supr_l: 6 pizzas
# spinach_supr_m: 4 pizzas
# spinach_supr_s: 7 pizzas
# thai_ckn_l: 29 pizzas
# thai_ckn_m: 9 pizzas
# thai_ckn_s: 8 pizzas
# the_greek_l: 6 pizzas
# the_greek_m: 5 pizzas
# the_greek_s: 6 pizzas
# the_greek_xl: 10 pizzas
# veggie_veg_l: 7 pizzas
# veggie_veg_m: 11 pizzas
# veggie_veg_s: 7 pizzas
# calabrese_s: 2 pizzas
# ital_veggie_l: 2 pizzas
# the_greek_xxl: 1 pizzas
# Total quantity of units forecasted to be sold in the next week: 924 pizzas
#
# MAPE scores:
# bbq_ckn_l: 0.21%
# bbq_ckn_m: 0.17%
# bbq_ckn_s: 0.45%
# big_meat_s: 0.16%
# brie_carre_s: 0.29%
# calabrese_l: 0.78%
# calabrese_m: 0.30%
# cali_ckn_l: 0.21%
# cali_ckn_m: 0.19%
# cali_ckn_s: 0.40%
# ckn_alfredo_l: 0.60%
# ckn_alfredo_m: 0.29%
# ckn_alfredo_s: 0.36%
# ckn_pesto_l: 0.32%
# ckn_pesto_m: 0.55%
# ckn_pesto_s: 0.51%
# classic_dlx_l: 0.43%
# classic_dlx_m: 0.18%
# classic_dlx_s: 0.19%
# five_cheese_l: 0.15%
# four_cheese_l: 0.18%
# four_cheese_m: 0.24%
# green_garden_l: 0.62%
# green_garden_m: 0.48%
# green_garden_s: 0.23%
# hawaiian_l: 0.20%
# hawaiian_m: 0.37%
# hawaiian_s: 0.21%
# ital_cpcllo_l: 0.23%
# ital_cpcllo_m: 0.34%
# ital_cpcllo_s: 0.36%
# ital_supr_l: 0.21%
# ital_supr_m: 0.22%
# ital_supr_s: 0.65%
# ital_veggie_m: 0.32%
# ital_veggie_s: 0.36%
# mediterraneo_l: 0.40%
# mediterraneo_m: 0.36%
# mediterraneo_s: 0.51%
# mexicana_l: 0.17%
# mexicana_m: 0.39%
# mexicana_s: 0.60%
# napolitana_l: 0.36%
# napolitana_m: 0.24%
# napolitana_s: 0.35%
# pep_msh_pep_l: 0.35%
# pep_msh_pep_m: 0.56%
# pep_msh_pep_s: 0.27%
# pepperoni_l: 0.28%
# pepperoni_m: 0.20%
# pepperoni_s: 0.23%
# peppr_salami_l: 0.30%
# peppr_salami_m: 0.26%
# peppr_salami_s: 0.53%
# prsc_argla_l: 0.55%
# prsc_argla_m: 0.20%
# prsc_argla_s: 0.42%
# sicilian_l: 0.21%
# sicilian_m: 0.28%
# sicilian_s: 0.45%
# soppressata_l: 0.42%
# soppressata_m: 0.41%
# soppressata_s: 0.46%
# southw_ckn_l: 0.21%
# southw_ckn_m: 0.29%
# southw_ckn_s: 0.49%
# spicy_ital_l: 0.18%
# spicy_ital_m: 0.46%
# spicy_ital_s: 0.32%
# spin_pesto_l: 0.56%
# spin_pesto_m: 0.68%
# spin_pesto_s: 0.36%
# spinach_fet_l: 0.34%
# spinach_fet_m: 0.38%
# spinach_fet_s: 0.39%
# spinach_supr_l: 0.65%
# spinach_supr_m: 0.42%
# spinach_supr_s: 0.41%
# thai_ckn_l: 0.16%
# thai_ckn_m: 0.32%
# thai_ckn_s: 0.29%
# the_greek_l: 0.43%
# the_greek_m: 0.46%
# the_greek_s: 0.52%
# the_greek_xl: 0.27%
# veggie_veg_l: 0.31%
# veggie_veg_m: 0.38%
# veggie_veg_s: 0.28%
# calabrese_s: 0.55%
# ital_veggie_l: 0.68%
# the_greek_xxl: 0.29%

# %% [markdown]
# XGBOOST Model

# %% [markdown]
# **Importing the Modules Needed**

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.model_selection import train_test_split
import warnings

# %% [markdown]
# **Creating the Lag Features**

# %%
def create_lag_features(df, lag=3):
    """Create lag features for time series forecasting."""
    lag_features = pd.DataFrame()

    for i in range(1, lag + 1):
        lag_features[f'lag_{i}'] = df.shift(i)

    lag_features['quantity'] = df
    lag_features.dropna(inplace=True)  # Remove rows with missing values due to lagging
    return lag_features

# %% [markdown]
# **Training the XGBoost and Forcasting the Quantity**

# %%
def forecast_sales_per_pizza_type_xgboost(pizza_type, data, periods=1, lag=3):
    """Forecast sales for a specific pizza type using XGBoost."""
    # Create lag features
    lagged_data = create_lag_features(data, lag=lag)

    # Split into features (X) and target (y)
    X = lagged_data.drop('quantity', axis=1)
    y = lagged_data['quantity']

    # Split data into train and test sets (80% train, 30% test)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)

    # Train the XGBoost model
    model = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=200, max_depth=4, learning_rate=0.01, random_state=42)
    model.fit(X_train, y_train)

    # Forecast the next period (next week)
    last_known_data = lagged_data.tail(1).drop('quantity', axis=1)  # Use the last known values as features
    forecast = model.predict(last_known_data)

    # Calculate MAPE on the test data
    y_pred = model.predict(X_test)
    mape = calculate_mape(y_test, y_pred)

    return pizza_type, forecast.tolist(), mape

# %% [markdown]
# **Forcasting the Quantity needed for each Pizza_name_id for Next Week**

# %%
def forecast_next_week_sales_by_pizza_type_xgboost(pizza_sales_weekly_by_pizza, periods=1, lag=3):
    """Forecast sales for the next week for all pizza types using XGBoost."""
    pizza_type_forecasts = {}
    mape_scores = {}

    # Get the last week's date range (for prediction display purposes)
    last_week = pizza_sales_weekly_by_pizza.index.max()
    next_week_start = last_week + pd.Timedelta(weeks=1)
    next_week_end = next_week_start + pd.Timedelta(days=6)

    # Loop through each pizza type
    for pizza_type in pizza_sales_weekly_by_pizza['pizza_name_id'].unique():
        # Filter the data for this pizza type
        pizza_type_data = pizza_sales_weekly_by_pizza[pizza_sales_weekly_by_pizza['pizza_name_id'] == pizza_type]

        # Forecast sales for the next week for this pizza type
        pizza_type, forecast, mape = forecast_sales_per_pizza_type_xgboost(pizza_type, pizza_type_data['quantity'], periods, lag)

        # Store the forecast and MAPE in dictionaries
        if forecast:
            pizza_type_forecasts[pizza_type] = forecast[0]  # Access the first value of the forecast list
            mape_scores[pizza_type] = mape

    return pizza_type_forecasts, mape_scores, next_week_start, next_week_end

# %% [markdown]
# **Displaying the Forecasted Results**

# %%
def display_forecast_results(forecasts, mape_scores, next_week_start, next_week_end):
    """Display the forecasted sales and MAPE for each pizza type."""
    print(f"Forecasted sales for the week {next_week_start.date()} to {next_week_end.date()}:")
    total_forecasted_quantity = 0  # To accumulate the forecasted quantities

    for pizza_type, forecast in forecasts.items():
        forecast = int(forecast)
        print(f'{pizza_type}: {forecast} pizzas')
        total_forecasted_quantity += forecast

    # Display total quantity of pizzas forecasted
    print(f"Total quantity of units forecasted to be sold in the next week: {total_forecasted_quantity} pizzas")

    # Display MAPE for each pizza type
    print("\nMAPE scores:")
    for pizza_type, mape in mape_scores.items():
        print(f"{pizza_type}: {mape:.2f}%")

# %% [markdown]
# **Main Function**

# %%
if __name__ == "__main__":
    # Prepare the data
    pizza_sales_weekly_by_pizza = prepare_data(pizza_sales_data)

    # Forecast pizza sales for the next week and calculate MAPE
    next_week_pizza_sales_forecasts, mape_scores, next_week_start, next_week_end = forecast_next_week_sales_by_pizza_type_xgboost(pizza_sales_weekly_by_pizza, periods=1, lag=3)

    # Display the forecasted results
    display_forecast_results(next_week_pizza_sales_forecasts, mape_scores, next_week_start, next_week_end)

    # Step 8: Create a DataFrame with pizza_name_id, next week quantity, and MAPE
    forecast_df = pd.DataFrame({
        'pizza_name_id': list(next_week_pizza_sales_forecasts.keys()),
        'next_week_quantity': list(next_week_pizza_sales_forecasts.values()),
        'MAPE': list(mape_scores.values())
    })

    forecast_df.to_csv("XGBOOST_Forcasted_Results.csv", index=False)
# Out:
# Forecasted sales for the week 2016-01-04 to 2016-01-10:
# bbq_ckn_l: 12 pizzas
# bbq_ckn_m: 14 pizzas
# bbq_ckn_s: 9 pizzas
# big_meat_s: 25 pizzas
# brie_carre_s: 9 pizzas
# calabrese_l: 3 pizzas
# calabrese_m: 4 pizzas
# cali_ckn_l: 19 pizzas
# cali_ckn_m: 12 pizzas
# cali_ckn_s: 9 pizzas
# ckn_alfredo_l: 2 pizzas
# ckn_alfredo_m: 11 pizzas
# ckn_alfredo_s: 2 pizzas
# ckn_pesto_l: 4 pizzas
# ckn_pesto_m: 4 pizzas
# ckn_pesto_s: 4 pizzas
# classic_dlx_l: 8 pizzas
# classic_dlx_m: 26 pizzas
# classic_dlx_s: 10 pizzas
# five_cheese_l: 15 pizzas
# four_cheese_l: 20 pizzas
# four_cheese_m: 6 pizzas
# green_garden_l: 2 pizzas
# green_garden_m: 4 pizzas
# green_garden_s: 16 pizzas
# hawaiian_l: 10 pizzas
# hawaiian_m: 7 pizzas
# hawaiian_s: 14 pizzas
# ital_cpcllo_l: 8 pizzas
# ital_cpcllo_m: 9 pizzas
# ital_cpcllo_s: 5 pizzas
# ital_supr_l: 9 pizzas
# ital_supr_m: 11 pizzas
# ital_supr_s: 4 pizzas
# ital_veggie_m: 5 pizzas
# ital_veggie_s: 5 pizzas
# mediterraneo_l: 3 pizzas
# mediterraneo_m: 4 pizzas
# mediterraneo_s: 3 pizzas
# mexicana_l: 10 pizzas
# mexicana_m: 4 pizzas
# mexicana_s: 3 pizzas
# napolitana_l: 7 pizzas
# napolitana_m: 4 pizzas
# napolitana_s: 12 pizzas
# pep_msh_pep_l: 5 pizzas
# pep_msh_pep_m: 8 pizzas
# pep_msh_pep_s: 5 pizzas
# pepperoni_l: 10 pizzas
# pepperoni_m: 16 pizzas
# pepperoni_s: 13 pizzas
# peppr_salami_l: 6 pizzas
# peppr_salami_m: 6 pizzas
# peppr_salami_s: 4 pizzas
# prsc_argla_l: 8 pizzas
# prsc_argla_m: 11 pizzas
# prsc_argla_s: 5 pizzas
# sicilian_l: 9 pizzas
# sicilian_m: 4 pizzas
# sicilian_s: 7 pizzas
# soppressata_l: 6 pizzas
# soppressata_m: 3 pizzas
# soppressata_s: 4 pizzas
# southw_ckn_l: 13 pizzas
# southw_ckn_m: 8 pizzas
# southw_ckn_s: 6 pizzas
# spicy_ital_l: 16 pizzas
# spicy_ital_m: 9 pizzas
# spicy_ital_s: 6 pizzas
# spin_pesto_l: 4 pizzas
# spin_pesto_m: 3 pizzas
# spin_pesto_s: 4 pizzas
# spinach_fet_l: 4 pizzas
# spinach_fet_m: 11 pizzas
# spinach_fet_s: 4 pizzas
# spinach_supr_l: 2 pizzas
# spinach_supr_m: 4 pizzas
# spinach_supr_s: 4 pizzas
# thai_ckn_l: 27 pizzas
# thai_ckn_m: 7 pizzas
# thai_ckn_s: 6 pizzas
# the_greek_l: 7 pizzas
# the_greek_m: 5 pizzas
# the_greek_s: 3 pizzas
# the_greek_xl: 7 pizzas
# veggie_veg_l: 9 pizzas
# veggie_veg_m: 7 pizzas
# veggie_veg_s: 9 pizzas
# calabrese_s: 1 pizzas
# ital_veggie_l: 2 pizzas
# the_greek_xxl: 1 pizzas
# Total quantity of units forecasted to be sold in the next week: 706 pizzas
#
# MAPE scores:
# bbq_ckn_l: 0.25%
# bbq_ckn_m: 0.31%
# bbq_ckn_s: 0.41%
# big_meat_s: 0.20%
# brie_carre_s: 0.47%
# calabrese_l: 0.79%
# calabrese_m: 0.31%
# cali_ckn_l: 0.29%
# cali_ckn_m: 0.20%
# cali_ckn_s: 0.53%
# ckn_alfredo_l: 0.55%
# ckn_alfredo_m: 0.27%
# ckn_alfredo_s: 0.57%
# ckn_pesto_l: 0.22%
# ckn_pesto_m: 0.77%
# ckn_pesto_s: 0.77%
# classic_dlx_l: 0.43%
# classic_dlx_m: 0.29%
# classic_dlx_s: 0.16%
# five_cheese_l: 0.16%
# four_cheese_l: 0.30%
# four_cheese_m: 0.30%
# green_garden_l: 0.55%
# green_garden_m: 0.61%
# green_garden_s: 0.31%
# hawaiian_l: 0.24%
# hawaiian_m: 0.47%
# hawaiian_s: 0.16%
# ital_cpcllo_l: 0.35%
# ital_cpcllo_m: 0.56%
# ital_cpcllo_s: 0.41%
# ital_supr_l: 0.26%
# ital_supr_m: 0.28%
# ital_supr_s: 1.24%
# ital_veggie_m: 0.49%
# ital_veggie_s: 0.48%
# mediterraneo_l: 0.41%
# mediterraneo_m: 0.30%
# mediterraneo_s: 0.40%
# mexicana_l: 0.16%
# mexicana_m: 0.43%
# mexicana_s: 0.36%
# napolitana_l: 0.33%
# napolitana_m: 0.19%
# napolitana_s: 0.33%
# pep_msh_pep_l: 0.49%
# pep_msh_pep_m: 0.36%
# pep_msh_pep_s: 0.19%
# pepperoni_l: 0.28%
# pepperoni_m: 0.27%
# pepperoni_s: 0.29%
# peppr_salami_l: 0.40%
# peppr_salami_m: 0.31%
# peppr_salami_s: 0.51%
# prsc_argla_l: 0.27%
# prsc_argla_m: 0.21%
# prsc_argla_s: 0.20%
# sicilian_l: 0.21%
# sicilian_m: 0.34%
# sicilian_s: 0.35%
# soppressata_l: 0.58%
# soppressata_m: 0.59%
# soppressata_s: 0.41%
# southw_ckn_l: 0.26%
# southw_ckn_m: 0.27%
# southw_ckn_s: 1.11%
# spicy_ital_l: 0.32%
# spicy_ital_m: 0.64%
# spicy_ital_s: 0.31%
# spin_pesto_l: 0.90%
# spin_pesto_m: 0.57%
# spin_pesto_s: 0.50%
# spinach_fet_l: 0.40%
# spinach_fet_m: 0.69%
# spinach_fet_s: 0.27%
# spinach_supr_l: 0.84%
# spinach_supr_m: 0.70%
# spinach_supr_s: 0.50%
# thai_ckn_l: 0.27%
# thai_ckn_m: 0.27%
# thai_ckn_s: 0.27%
# the_greek_l: 1.29%
# the_greek_m: 0.93%
# the_greek_s: 0.32%
# the_greek_xl: 0.21%
# veggie_veg_l: 0.44%
# veggie_veg_m: 0.31%
# veggie_veg_s: 0.28%
# calabrese_s: 0.59%
# ital_veggie_l: 0.48%
# the_greek_xxl: 0.20%

# %% [markdown]
# **Now the Forcasted Quantity for all the Model is done Let rename the Columns in all the Dataset for Clear Understanding**

# %%
Arima_Model=pd.read_csv('/content/ARIMA_Forecasted_result.csv')
Arima_Model.head()
# Out:
#   pizza_name_id  predicted_quantity      mape
# 0     bbq_ckn_l                  19  0.328097
# 1     bbq_ckn_m                  18  0.421951
# 2     bbq_ckn_s                   8  0.284963
# 3    big_meat_s                  37  0.211025
# 4  brie_carre_s                   9  0.380018

# %% [markdown]
# **Lets_ rename It**

# %%
Arima_Model.rename(columns={'predicted_quantity':'Arima_Predicted_Quantity','mape':'Arima_mape'},inplace=True)
Arima_Model.head()
# Out:
#   pizza_name_id  Arima_Predicted_Quantity  Arima_mape
# 0     bbq_ckn_l                        19    0.328097
# 1     bbq_ckn_m                        18    0.421951
# 2     bbq_ckn_s                         8    0.284963
# 3    big_meat_s                        37    0.211025
# 4  brie_carre_s                         9    0.380018

# %% [markdown]
# **Sarima Model**

# %%
Sarima_Model=pd.read_csv('/content/SARIMA_Forecasted_Result.csv')
Sarima_Model.head()
# Out:
#   pizza_name_id  next_week_quantity      MAPE
# 0     bbq_ckn_l           17.670201  0.330073
# 1     bbq_ckn_m           18.621751  0.425010
# 2     bbq_ckn_s            9.672490  0.373132
# 3    big_meat_s           39.036142  0.241102
# 4  brie_carre_s            8.414301  0.390179

# %%
Sarima_Model.rename(columns={'next_week_quantity':'Sarima_Predicted_Quantity','MAPE':'Sarima_mape'},inplace=True)
Sarima_Model.head()
# Out:
#   pizza_name_id  Sarima_Predicted_Quantity  Sarima_mape
# 0     bbq_ckn_l                  17.670201     0.330073
# 1     bbq_ckn_m                  18.621751     0.425010
# 2     bbq_ckn_s                   9.672490     0.373132
# 3    big_meat_s                  39.036142     0.241102
# 4  brie_carre_s                   8.414301     0.390179

# %% [markdown]
# Prophet Model

# %%
Prophet_Model=pd.read_csv('/content/Prophet_Forecasted_Result.csv')
Prophet_Model.head()
# Out:
#   pizza_name_id  next_week_quantity      MAPE
# 0     bbq_ckn_l           16.617704  0.209953
# 1     bbq_ckn_m           18.712740  0.169154
# 2     bbq_ckn_s            9.960162  0.449412
# 3    big_meat_s           40.726617  0.158759
# 4  brie_carre_s            9.825305  0.293974

# %%
Prophet_Model.rename(columns={'next_week_quantity':'Prophet_Predicted_Quantity','MAPE':'Prophet_mape'},inplace=True)
Prophet_Model.head()
# Out:
#   pizza_name_id  Prophet_Predicted_Quantity  Prophet_mape
# 0     bbq_ckn_l                   16.617704      0.209953
# 1     bbq_ckn_m                   18.712740      0.169154
# 2     bbq_ckn_s                    9.960162      0.449412
# 3    big_meat_s                   40.726617      0.158759
# 4  brie_carre_s                    9.825305      0.293974

# %%
XGBoost_Model=pd.read_csv('/content/XGBOOST_Forcasted_Results.csv')
XGBoost_Model.head()
# Out:
#   pizza_name_id  next_week_quantity      MAPE
# 0     bbq_ckn_l           12.182958  0.248165
# 1     bbq_ckn_m           14.152276  0.305642
# 2     bbq_ckn_s            9.234591  0.408613
# 3    big_meat_s           25.036869  0.195002
# 4  brie_carre_s            9.471176  0.473958

# %%
XGBoost_Model.rename(columns={'next_week_quantity':'XGBoost_Predicted_Quantity','MAPE':'XGBoost_mape'},inplace=True)
XGBoost_Model.head()
# Out:
#   pizza_name_id  XGBoost_Predicted_Quantity  XGBoost_mape
# 0     bbq_ckn_l                   12.182958      0.248165
# 1     bbq_ckn_m                   14.152276      0.305642
# 2     bbq_ckn_s                    9.234591      0.408613
# 3    big_meat_s                   25.036869      0.195002
# 4  brie_carre_s                    9.471176      0.473958

# %% [markdown]
# **Now Lets Merge the Four Dataframe with respect to pizza_name_id since it was common in all four DataFrame**

# %%
import pandas as pd
merged_df = pd.merge(Arima_Model, Sarima_Model, on='pizza_name_id', how='outer')
merged_df = pd.merge(merged_df, Prophet_Model, on='pizza_name_id', how='outer')
merged_df = pd.merge(merged_df, XGBoost_Model, on='pizza_name_id', how='outer')
merged_df.head()
# Out:
#   pizza_name_id  Arima_Predicted_Quantity  Arima_mape  \
# 0     bbq_ckn_l                        19    0.328097
# 1     bbq_ckn_m                        18    0.421951
# 2     bbq_ckn_s                         8    0.284963
# 3    big_meat_s                        37    0.211025
# 4  brie_carre_s                         9    0.380018
#
#    Sarima_Predicted_Quantity  Sarima_mape  Prophet_Predicted_Quantity  \
# 0                  17.670201     0.330073                   16.617704
# 1                  18.621751     0.425010                   18.712740
# 2                   9.672490     0.373132                    9.960162
# 3                  39.036142     0.241102                   40.726617
# 4                   8.414301     0.390179                    9.825305
#
#    Prophet_mape  XGBoost_Predicted_Quantity  XGBoost_mape
# 0      0.209953                   12.182958      0.248165
# 1      0.169154                   14.152276      0.305642
# 2      0.449412                    9.234591      0.408613
# 3      0.158759                   25.036869      0.195002
# 4      0.293974                    9.471176      0.473958

# %% [markdown]
# **Now Export This Dataframe If incase it might Usefull for Future**

# %%
merged_df.to_csv('Combined_forecasted_result.csv', index=False)

# %% [markdown]
# **Now Find out a Final quantity for each model based on the Models performances**

# %%
import pandas as pd

# Load the CSV file
file_path = '/content/Combined_forecasted_result.csv'
data = pd.read_csv(file_path)

# Function to find the best model based on the lowest MAPE score
def find_best_model(row):
    # Dictionary to map model names to their MAPE scores and quantities
    models = {
        'Arima': (row['Arima_mape'], row['Arima_Predicted_Quantity']),
        'Sarima': (row['Sarima_mape'], row['Sarima_Predicted_Quantity']),
        'Prophet': (row['Prophet_mape'], row['Prophet_Predicted_Quantity']),
        'XGBoost': (row['XGBoost_mape'], row['XGBoost_Predicted_Quantity'])
    }

    # Find the model with the lowest MAPE score
    best_model = min(models, key=lambda k: models[k][0])

    # Return the best model's quantity, lowest MAPE score, and model name
    return pd.Series({
        'quantity': models[best_model][1],
        'lowest_mape_score': models[best_model][0],
        'best_model': best_model
    })

# Apply the function to each row to create new columns
data[['quantity', 'lowest_mape_score', 'best_model']] = data.apply(find_best_model, axis=1)

data.to_csv('Final_ForeCasted_Data.csv', index=False)

# Display the result
print(data.head())
# Out:
#   pizza_name_id  Arima_Predicted_Quantity  Arima_mape  \
# 0     bbq_ckn_l                        19    0.328097
# 1     bbq_ckn_m                        18    0.421951
# 2     bbq_ckn_s                         8    0.284963
# 3    big_meat_s                        37    0.211025
# 4  brie_carre_s                         9    0.380018
#
#    Sarima_Predicted_Quantity  Sarima_mape  Prophet_Predicted_Quantity  \
# 0                  17.670201     0.330073                   16.617704
# 1                  18.621751     0.425010                   18.712740
# 2                   9.672490     0.373132                    9.960162
# 3                  39.036142     0.241102                   40.726617
# 4                   8.414301     0.390179                    9.825305
#
#    Prophet_mape  XGBoost_Predicted_Quantity  XGBoost_mape   quantity  \
# 0      0.209953                   12.182958      0.248165  16.617704
# 1      0.169154                   14.152276      0.305642  18.712740
# 2      0.449412                    9.234591      0.408613   8.000000
# 3      0.158759                   25.036869      0.195002  40.726617
# 4      0.293974                    9.471176      0.473958   9.825305
#
#    lowest_mape_score best_model
# 0           0.209953    Prophet
# 1           0.169154    Prophet
# 2           0.284963      Arima
# 3           0.158759    Prophet
# 4           0.293974    Prophet

# %% [markdown]
# **Let's load and See**

# %%
Final_Quantity=pd.read_csv('/content/Final_ForeCasted_Data.csv')
Final_Quantity.head()
# Out:
#   pizza_name_id  Arima_Predicted_Quantity  Arima_mape  \
# 0     bbq_ckn_l                        19    0.328097
# 1     bbq_ckn_m                        18    0.421951
# 2     bbq_ckn_s                         8    0.284963
# 3    big_meat_s                        37    0.211025
# 4  brie_carre_s                         9    0.380018
#
#    Sarima_Predicted_Quantity  Sarima_mape  Prophet_Predicted_Quantity  \
# 0                  17.670201     0.330073                   16.617704
# 1                  18.621751     0.425010                   18.712740
# 2                   9.672490     0.373132                    9.960162
# 3                  39.036142     0.241102                   40.726617
# 4                   8.414301     0.390179                    9.825305
#
#    Prophet_mape  XGBoost_Predicted_Quantity  XGBoost_mape   quantity  \
# 0      0.209953                   12.182958      0.248165  16.617704
# 1      0.169154                   14.152276      0.305642  18.712740
# 2      0.449412                    9.234591      0.408613   8.000000
# 3      0.158759                   25.036869      0.195002  40.726617
# 4      0.293974                    9.471176      0.473958   9.825305
#
#    lowest_mape_score best_model
# 0           0.209953    Prophet
# 1           0.169154    Prophet
# 2           0.284963      Arima
# 3           0.158759    Prophet
# 4           0.293974    Prophet

# %%
# Round the 'quantity' column and update it in place
#Final_Quantity['quantity'] = Final_Quantity['quantity'].round()
print(Final_Quantity.quantity.sum())
print((Final_Quantity.lowest_mape_score.median()))
Final_Quantity.head()
# Out:
# 902.0
# 0.3045989720277652
#   pizza_name_id  Arima_Predicted_Quantity  Arima_mape  \
# 0     bbq_ckn_l                        19    0.328097
# 1     bbq_ckn_m                        18    0.421951
# 2     bbq_ckn_s                         8    0.284963
# 3    big_meat_s                        37    0.211025
# 4  brie_carre_s                         9    0.380018
#
#    Sarima_Predicted_Quantity  Sarima_mape  Prophet_Predicted_Quantity  \
# 0                  17.670201     0.330073                   16.617704
# 1                  18.621751     0.425010                   18.712740
# 2                   9.672490     0.373132                    9.960162
# 3                  39.036142     0.241102                   40.726617
# 4                   8.414301     0.390179                    9.825305
#
#    Prophet_mape  XGBoost_Predicted_Quantity  XGBoost_mape  quantity  \
# 0      0.209953                   12.182958      0.248165      17.0
# 1      0.169154                   14.152276      0.305642      19.0
# 2      0.449412                    9.234591      0.408613       8.0
# 3      0.158759                   25.036869      0.195002      41.0
# 4      0.293974                    9.471176      0.473958      10.0
#
#    lowest_mape_score best_model
# 0           0.209953    Prophet
# 1           0.169154    Prophet
# 2           0.284963      Arima
# 3           0.158759    Prophet
# 4           0.293974    Prophet

# %% [markdown]
# > So the total Quantity Needed for the Next Week is **902** and the overall Mape score is **0.30**

# %%
# now take only needed Columns
Final_Quantity=Final_Quantity[['pizza_name_id','quantity','lowest_mape_score','best_model']]
Final_Quantity.head()
# Out:
#   pizza_name_id  quantity  lowest_mape_score best_model
# 0     bbq_ckn_l      17.0           0.209953    Prophet
# 1     bbq_ckn_m      19.0           0.169154    Prophet
# 2     bbq_ckn_s       8.0           0.284963      Arima
# 3    big_meat_s      41.0           0.158759    Prophet
# 4  brie_carre_s      10.0           0.293974    Prophet

# %% [markdown]
# # Merging with the Ingredient Dataset

# %%
import pandas as pd

# Use pd.read_excel to read .xlsx files and specify the encoding
Pizza_ingredient = pd.read_excel(r'/content/Pizza_ingredients.xlsx', engine='openpyxl')
Pizza_ingredient.head()
# Out:
#   pizza_name_id                  pizza_name  pizza_ingredients  \
# 0     bbq_ckn_l  The Barbecue Chicken Pizza  Barbecued Chicken
# 1     bbq_ckn_l  The Barbecue Chicken Pizza        Red Peppers
# 2     bbq_ckn_l  The Barbecue Chicken Pizza      Green Peppers
# 3     bbq_ckn_l  The Barbecue Chicken Pizza           Tomatoes
# 4     bbq_ckn_l  The Barbecue Chicken Pizza         Red Onions
#
#    Items_Qty_In_Grams
# 0                40.0
# 1                15.0
# 2                20.0
# 3                30.0
# 4                60.0

# %%
import pandas as pd
# Merge Final_Quantity and Pizza_ingredient datasets on 'pizza_name_id'
merged_df = pd.merge(Final_Quantity, Pizza_ingredient, on='pizza_name_id', how='left')

# Display the merged DataFrame
merged_df.head()
# Out:
#   pizza_name_id  quantity  lowest_mape_score best_model  \
# 0     bbq_ckn_l      17.0           0.209953    Prophet
# 1     bbq_ckn_l      17.0           0.209953    Prophet
# 2     bbq_ckn_l      17.0           0.209953    Prophet
# 3     bbq_ckn_l      17.0           0.209953    Prophet
# 4     bbq_ckn_l      17.0           0.209953    Prophet
#
#                    pizza_name  pizza_ingredients  Items_Qty_In_Grams
# 0  The Barbecue Chicken Pizza  Barbecued Chicken                40.0
# 1  The Barbecue Chicken Pizza        Red Peppers                15.0
# 2  The Barbecue Chicken Pizza      Green Peppers                20.0
# 3  The Barbecue Chicken Pizza           Tomatoes                30.0
# 4  The Barbecue Chicken Pizza         Red Onions                60.0

# %% [markdown]
# **Lets Find out the Actuall Quantity Needed for Each Ingredient**

# %%
merged_df['Inc_Quantity']=merged_df['quantity']*merged_df['Items_Qty_In_Grams']
merged_df.head()
# Out:
#   pizza_name_id  quantity  lowest_mape_score best_model  \
# 0     bbq_ckn_l      17.0           0.209953    Prophet
# 1     bbq_ckn_l      17.0           0.209953    Prophet
# 2     bbq_ckn_l      17.0           0.209953    Prophet
# 3     bbq_ckn_l      17.0           0.209953    Prophet
# 4     bbq_ckn_l      17.0           0.209953    Prophet
#
#                    pizza_name  pizza_ingredients  Items_Qty_In_Grams  \
# 0  The Barbecue Chicken Pizza  Barbecued Chicken                40.0
# 1  The Barbecue Chicken Pizza        Red Peppers                15.0
# 2  The Barbecue Chicken Pizza      Green Peppers                20.0
# 3  The Barbecue Chicken Pizza           Tomatoes                30.0
# 4  The Barbecue Chicken Pizza         Red Onions                60.0
#
#    Inc_Quantity
# 0         680.0
# 1         255.0
# 2         340.0
# 3         510.0
# 4        1020.0

# %% [markdown]
# **Exporting the Finale Forecated Quantity for each ingredient**

# %%
#Final=merged_df[['pizza_name_id','pizza_name','pizza_ingredients','Inc_Quantity']]
Final.head(20)
# Out:
#    pizza_name_id                  pizza_name  pizza_ingredients  Inc_Quantity
# 0      bbq_ckn_l  The Barbecue Chicken Pizza  Barbecued Chicken         680.0
# 1      bbq_ckn_l  The Barbecue Chicken Pizza        Red Peppers         255.0
# 2      bbq_ckn_l  The Barbecue Chicken Pizza      Green Peppers         340.0
# 3      bbq_ckn_l  The Barbecue Chicken Pizza           Tomatoes         510.0
# 4      bbq_ckn_l  The Barbecue Chicken Pizza         Red Onions        1020.0
# 5      bbq_ckn_l  The Barbecue Chicken Pizza     Barbecue Sauce         255.0
# 6      bbq_ckn_m  The Barbecue Chicken Pizza  Barbecued Chicken         570.0
# 7      bbq_ckn_m  The Barbecue Chicken Pizza        Red Peppers         190.0
# 8      bbq_ckn_m  The Barbecue Chicken Pizza      Green Peppers         285.0
# 9      bbq_ckn_m  The Barbecue Chicken Pizza           Tomatoes         380.0
# 10     bbq_ckn_m  The Barbecue Chicken Pizza         Red Onions         760.0
# 11     bbq_ckn_m  The Barbecue Chicken Pizza     Barbecue Sauce         190.0
# 12     bbq_ckn_s  The Barbecue Chicken Pizza  Barbecued Chicken         160.0
# 13     bbq_ckn_s  The Barbecue Chicken Pizza        Red Peppers          40.0
# 14     bbq_ckn_s  The Barbecue Chicken Pizza      Green Peppers         160.0
# 15     bbq_ckn_s  The Barbecue Chicken Pizza           Tomatoes          80.0
# 16     bbq_ckn_s  The Barbecue Chicken Pizza         Red Onions         160.0
# 17     bbq_ckn_s  The Barbecue Chicken Pizza     Barbecue Sauce          40.0
# 18    big_meat_s          The Big Meat Pizza              Bacon        6150.0
# 19    big_meat_s          The Big Meat Pizza          Pepperoni        2050.0

# %%
import pandas as pd
# Group by 'pizza_ingredients' and sum the 'Inc_Quantity'
ingredient_quantities = Final.groupby('pizza_ingredients')['Inc_Quantity'].sum()

# Create a DataFrame from the grouped data
purchase_order_df = pd.DataFrame({'Ingredient': ingredient_quantities.index, 'Total_Quantity_Needed': ingredient_quantities.values})

# Export the DataFrame to a CSV file named 'Purchace_order.csv'
purchase_order_df.to_csv('Purchace_order.csv', index=False)

# Print a message to indicate that the file has been exported
print("Purchase order exported to Purchace_order.csv")
# Out:
# Purchase order exported to Purchace_order.csv

# %%
Final.to_csv('Final_Inc_Quantity.csv', index=False)
